# %% [markdown]
# # Algoritmo GRASP

# %% [markdown]
# ## Leyendo datos de TSPData

# %% [markdown]
# Primero vamos a coger una distribución de ciudades reales, en particular de Argentina.

# %% [markdown]
# Mostremos el texto (para enseñar el formato)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
# Tamaño de ciudades
num_ciudades=1000

# %%
from StringIO import StringIO

df = pd.read_table('ar9152.tsp', sep=' ', skiprows=7, skipfooter=1, names=['x','y'], engine='python')

df = df[:-1]
print df.tail()
# Out:
#                x           y
# 9147  34383.0556  58848.8889
# 9148  34411.1111  58798.3333
# 9149  34813.3333  58475.2778
# 9150  34878.0556  58135.8333
# 9151  34917.2222  58386.9444

# %%
posiciones=[(float(x),float(y)) for x, y in zip(df['x'],df['y'])]
pos = np.asarray(posiciones)
max_pos = pos.max(0)
min_pos = pos.min(0)
ratio_pos = max_pos - min_pos
pos = (pos-min_pos)/ratio_pos
posiciones = map(tuple, pos)
posiciones=posiciones[:1000]
print (posiciones)
# Out:
# [(0.43563856795998135, 0.46515679523546483), (0.38515901122144475, 0.26045296038406435), (0.90156486632855637, 0.97473867765633926), (0.48207975822101995, 0.73344947688754258), (0.41023893850556392, 0.34098432289370101), (0.38465421465456412, 0.77874564595600293), (0.16658253390551989, 0.058362371181816065), (0.38313982798269575, 0.49738676219056938), (0.057041899992890652, 0.57665505152727359), (0.31802120109235615, 0.31445993260358884), (0.31802120109235615, 0.31445993260358884), (0.10701666016454663, 0.62108013871268308), (0.28773346765498892, 0.55052264730056211), (0.48561332813163732, 0.48519163673378329), (0.46340232159171901, 0.34059233683030032), (0.41544674465881198, 0.37891986128731686), (0.36042402790467032, 0.36324041875128998), (0.41102978454212041, 0.37846980379524348), (0.29581019758121135, 0.77090592468798946), (0.21049974738970242, 0.27090592207474895), (0.13326602712441593, 0.56620208983658893), (0.38644623989253285, 0.25965447431995553), (0.3715295311746295, 0.37369338044197459), (0.36092882447155095, 0.41463414532166221), (0.32660272758545922, 0.78222996826172486), (0.15598182720244136, 0.052264808453423017), (0.31448763421051229, 0.7717770065710402), (0.41393235798694361, 0.27351916249742009), (0.096920746999575216, 0.618466898290012), (0.20191822392537287, 0.70121951515891912), (0.050479556738536588, 0.46777003565813596), (0.4442200914243109, 0.46689895377508522), (0.51085310498651881, 0.37195122190235413), (0.1766784470704913, 0.40331010697440794), (0.19485108713291166, 0.59146341740673081), (0.29278142423747461, 0.78832752576363674), (0.46441191472548021, 0.43292682828036028), (0.46441191472548021, 0.43292682828036028), (0.41393235798694361, 0.27351916249742009), (0.29328622080435524, 0.43118466974073988), (0.29328622080435524, 0.43118466974073988), (0.37833585726568808, 0.27414343950199227), (0.33720343428853777, 0.37804877940426612), (0.3937405346857743, 0.38414634213265919), (0.36977957256963184, 0.28144599352168292), (0.13124684691444041, 0.61411149932772047), (0.07168097014469367, 0.60017421533131388), (0.39878849126825999, 0.28222996564848429), (0.35133770787346014, 0.80226480976004333), (0.12670368689883535, 0.36062717832861879), (0.17869762728046679, 0.61062717702199854), (0.14134275705063834, 0.29790940818451117), (0.51539626500212399, 0.85801394051918822), (0.56991418518938497, 0.51306620472659625), (0.18273599375796476, 0.55400696960628393), (0.36092882447155095, 0.66811846632076388), (0.91721352961412062, 0.77961672783905367), (0.55426552190382072, 0.86672473844377129), (0.45784957147112615, 0.49651568030751864), (0.053003533515392692, 0.56533101318001933), (0.20646138394097793, 0.16550522851133326), (0.28773346765498892, 0.23344947950078318), (0.21201413406157077, 0.22909407531201051), (0.4926804649240985, 0.89198606601391317), (0.16607774036741277, 0.62020906205611348), (0.17920242384734741, 0.48693380049988477), (0.046945986827919242, 0.54965157064399239), (0.49217566835721788, 0.22648083488933937), (0.0095911165980907924, 0.64634146628282496), (0.21857647731592483, 0.24477351784803741), (0.28975265089373792, 0.56010453233467705), (0.28975265089373792, 0.56010453233467705), (0.19787986047664838, 0.62630661955802547), (0.25694094067951451, 0.73257840023097298), (0.27410398760817367, 0.30400697091290424), (0.29025744746061849, 0.24128920076879662), (0.43311458815435172, 0.33536585598495805), (0.17011610381613723, 0.079268294563185265), (0.16961130724925663, 0.077526130797083773), (0.15446744053057299, 0.043554005302358818), (0.21504290740530752, 0.618466898290012), (0.14941948697686078, 0.60975610036542893), (0.28117112742940831, 0.51916376222850824), (0.17920242384734741, 0.48693380049988477), (0.33215547770605203, 0.37369338044197459), (0.0065623432543540673, 0.61759582163344229), (0.0075719333593418136, 0.61759582163344229), (0.21605250053906874, 0.27439024438047083), (0.31044926773301434, 0.24128920076879662), (0.21302372719533202, 0.27613240292009122), (0.11256941028513946, 0.590592335 ...

# %% [markdown]
# Ahora ya hemos puesto el formato de las posiciones y normalizado los datos. A continuación declararemos la matriz de costes.

# %% [markdown]
# #Cálculo de matriz de costes

# %%
from scipy.spatial.distance import euclidean as distance

def get_matrix_costes(posiciones):
    num = len(posiciones)
    costes = np.array([distance(posiciones[c1],posiciones[c2]) for c1 in range(num) for c2 in range(num)])
    return costes.reshape((num, num))

# %% [markdown]
# Hemos declarado la función de la matriz de costes y ahora llamaremos con los datos de las posiciones para calcular la matriz de costes asociada.

# %%
costes = get_matrix_costes(posiciones)
print (costes)
# Out:
# [[ 0.          0.21083606  0.69047883 ...,  0.32414658  0.2792496
#    0.29056059]
#  [ 0.21083606  0.          0.88140745 ...,  0.37827615  0.4061588
#    0.39974159]
#  [ 0.69047883  0.88140745  0.         ...,  0.90236424  0.77748313
#    0.81120306]
#  ...,
#  [ 0.32414658  0.37827615  0.90236424 ...,  0.          0.13229269
#    0.09829191]
#  [ 0.2792496   0.4061588   0.77748313 ...,  0.13229269  0.          0.03449672]
#  [ 0.29056059  0.39974159  0.81120306 ...,  0.09829191  0.03449672  0.        ]]

# %% [markdown]
# Esta es la matriz de costes obtenida una vez que se han normalizado los datos.

# %% [markdown]
# #FITNESS

# %%
def fitness(solucion, costes):
    sum = 0
    
    for i in range(num_ciudades-1):
        c1 = solucion[i]
        c2 = solucion[i+1]
        sum += costes[c1,c2]
    # Volver a la ciudad inicial
    ciudad_final = solucion[num_ciudades-1]
    ciudad_origen = solucion[0]
    sum += costes[ciudad_final, ciudad_origen]
    return sum

# %% [markdown]
# ## Búsqueda aleatoria

# %%
def random_sol(num):
    return np.random.permutation(num)

# %%
from sys import maxint

def random_search(costes, evaluations):
    num = costes.shape[0]
    best = maxint
    best_sol = []
    
    for r in range(evaluations):
        solucion = random_sol(num)
        fitness_sol = fitness(solucion, costes)
        if(fitness_sol < best):
                best = fitness_sol
                best_sol = solucion
            
    return best_sol

# %%
best_solucion =  random_search(costes, 50000)

# %% [markdown]
# #Algoritmo de GRASP

# %%
#Sea pendientes un vector de ciudades por v i s i t a r costes la matriz de costes y c1 la ciudad destino con menor distancia c2 se calcula como:
#distancias = costes[c1] 
#distancias_destino = distancias[pendientes] 
#c2= pendientes[distancias_destino.argmin()]

def construccion_solucion_greedy(costes):
     
    pendientes= np.arange(1000)
    # print "Pendientes:"
    #print pendientes
    pendientes=np.delete(pendientes,0)
    #print "Eliminamos el primero:"
    #print pendientes
    camino_solucion= []
    c1=0
    camino_solucion.append(c1)
    num_ciudades = len(pendientes)
    
    for i in range(num_ciudades):

    
        distancias=costes[c1]
        distancias_destino = distancias[pendientes]
        distancias_destino2 = distancias_destino[:]
        c2 = pendientes[distancias_destino.argmin()]
        idCiudadesCercanas= []
        
        if (len(distancias_destino2) >= 1):
            c1=0
            id1= distancias_destino2.argmin()
            idCiudadesCercanas.append(id1)
            distancias_destino2=np.delete(distancias_destino2,id1)
        
        
        if (len(distancias_destino2) >= 2):
            c1=idCiudadesCercanas[randint(0,1)];
            id2= distancias_destino2.argmin();
            idCiudadesCercanas.append(id2)
            distancias_destino2=np.delete(distancias_destino2,id2)
      
            
        if (len(distancias_destino2) >= 3):
            c1=idCiudadesCercanas[randint(0,2)];
            id3= distancias_destino2.argmin();
            idCiudadesCercanas.append(id3)
            distancias_destino2=np.delete(distancias_destino2,id3)
       
        
        #Devolver una de las 3 ciudades obtenidas de forma aleatoria.
        #c1=idCiudadesCercanas[randint(0,3)];
        camino_solucion.append(c1)
        pendientes=np.delete(pendientes, c1)
        
    # Conjunto de vertices que son la solución
    return camino_solucion

# %%
A=construccion_solucion_greedy(costes)
print A
# Out:
 439, 394, 422, 79, 26, 11, 449, 153, 42, 14, 152, 92, 287, 91, 9, 3, 302, 358, 62, 21, 168, 60, 17, 108, 23, 8, 14, 385, 423, 69, 350, 39, 164, 145, 223, 57, 92, 363, 22, 395, 87, 149, 32, 180, 430, 88, 171, 164, 105, 20, 195, 168, 296, 221, 266, 110, 406, 187, 312, 349, 19, 406, 114, 345, 70, 199, 393, 248, 123, 329, 267, 69, 184, 44, 288, 144, 85, 225, 265, 189, 157, 53, 60, 270, 118, 19, 389, 96, 271, 256, 340, 339, 273, 173, 269, 304, 74, 116, 149, 330, 78, 48, 37, 221, 92, 107, 325, 162, 125, 20, 182, 261, 346, 92, 363, 43, 7, 45, 351, 51, 50, 362, 45, 347, 359, 73, 186, 114, 113, 42, 128, 295, 290, 247, 71, 160, 326, 158, 28, 132, 21, 187, 214, 189, 213, 81, 51, 332, 189, 1, 60, 290, 31, 6, 155, 24, 28, 122, 112, 265, 54, 236, 121, 302, 242, 315, 55, 198, 35, 6, 296, 122, 202, 89, 292, 180, 221, 290, 215, 96, 220, 170, 197, 54, 68, 134, 18, 53, 168, 28, 26, 173, 198, 161, 156, 285, 218, 150, 172, 223, 9, 2, 0, 163, 268, 61, 25, 48, 15, 2, 238, 28, 102, 85, 262, 97, 198, 29, 77, 24, 31, 114, 212, 39, 141, 245, 79, 23, 202, 222, 61, 28, 89, 178, 169, 23, 67, 9, 89, 77, 76, 92, 29, 181, 238, 91, 10, 68, 182, 89, 132, 177, 115, 26, 128, 161, 15, 18, 217, 214, 49, 109, 50, 220, 75, 176, 55, 130, 23, 168, 56, 86, 119, 131, 21, 22, 2, 181, 33, 113, 150, 115, 37, 156, 45, 192, 122, 121, 131, 131, 47, 123, 160, 64, 6, 2, 163, 114, 119, 116, 133, 9, 132, 107, 96, 121, 82, 142, 131, 80, 174, 13, 77, 78, 123, 48, 33, 50, 64, 160, 118, 12, 68, 74, 35, 22, 28, 54, 116, 14, 7, 112, 45, 3, 90, 57, 122, 41, 10, 39, 102, 6, 9, 42, 18, 77, 89, 2, 114, 124 ...

# %%
from sys import maxint

def grasp(costes, evaluations):
    num = costes.shape[0]
    best = maxint
    best_sol = []
    
    for r in range(evaluations):
        solucion = construccion_solucion_greedy(costes) 
        fitness_solucion=fitness(solucion, costes)
        if (fitness_solucion < best):
            best = fitness_solucion
            best_sol = solucion
            
    return best_sol

# %%
distancia1=0
distancia2=0
    
for r in range(10):
    distancia1+= fitness(grasp(costes,500),costes)
    distancia2+= fitness(random_search(costes,500),costes)
    
distanciat1= distancia1/10
distanciat2= distancia2/10

print "Distancia del algoritmo grasp es: "+"%.2f" % distanciat1
print "La distancia del algoritmo aleatorio es: "+"%.2f" % distanciat2
# Out:
# Distancia del algoritmo grasp es: 281.29
# La distancia del algoritmo aleatorio es: 285.67
